# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon City Campus</center>
#
# ---
# > > > > > > > >>>>>>>> <center><h4> Hands-on Activity 7.1 Data Collection and Wrangling</h4></center>
#
#
#
#
#
#
#
# ---
# <center>
#
# | Course: CPE 311 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Computational Thinking with Python | **Date Performed:** | 03/20/24 |
# | **Section**: CPE22S3 | **Date Submitted:** | |
# | **Student Name**: Jhillian M. Cabos | **Instructor's Name:** Roman Richard|
# </center>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
netflix_df = pd.read_csv('nflx.csv')
netflix_df.head()
# Out:
#          date    open    high       low   close    volume
# 0  2018-01-02  196.10  201.65  195.4200  201.07  10966889
# 1  2018-01-03  202.05  206.21  201.5000  205.05   8591369
# 2  2018-01-04  206.20  207.05  204.0006  205.63   6029616
# 3  2018-01-05  207.25  210.02  205.5900  209.99   7033240
# 4  2018-01-08  210.02  212.50  208.4400  212.05   5580178

# %% [markdown]
# Netflix Dataframe and renaming

# %%
netflix_df = pd.read_csv('nflx.csv', usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
netflix_df = netflix_df.rename(columns={
    'date': 'nflxdate',
    'open': 'nflxopen',
    'high': 'nflxhigh',
    'low': 'nflxlow',
    'close': 'nflxclose',
    'volume': 'nflxvolume'})
netflix_df.to_csv('netflix.csv', index=False)
netflix_df.head()
# Out:
#      nflxdate  nflxopen  nflxhigh   nflxlow  nflxclose  nflxvolume
# 0  2018-01-02    196.10    201.65  195.4200     201.07    10966889
# 1  2018-01-03    202.05    206.21  201.5000     205.05     8591369
# 2  2018-01-04    206.20    207.05  204.0006     205.63     6029616
# 3  2018-01-05    207.25    210.02  205.5900     209.99     7033240
# 4  2018-01-08    210.02    212.50  208.4400     212.05     5580178

# %% [markdown]
# Facebook Dataframe and renaming

# %%
fb_df = pd.read_csv('fb.csv')
fb_df.head()
# Out:
#          date    open    high       low   close    volume
# 0  2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 1  2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2  2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 3  2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 4  2018-01-08  187.20  188.90  186.3300  188.28  17994726

# %%
fb_df = pd.read_csv('fb.csv', usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
fb_df = fb_df.rename(columns={
    'date': 'fbdate',
    'open': 'fbopen',
    'high': 'fbhigh',
    'low': 'fblow',
    'close': 'fbclose',
    'volume': 'fbvolume'})
fb_df.head()
# Out:
#        fbdate  fbopen  fbhigh     fblow  fbclose  fbvolume
# 0  2018-01-02  177.68  181.58  177.5500   181.42  18151903
# 1  2018-01-03  181.88  184.78  181.3300   184.67  16886563
# 2  2018-01-04  184.90  186.21  184.0996   184.33  13880896
# 3  2018-01-05  185.59  186.90  184.9300   186.85  13574535
# 4  2018-01-08  187.20  188.90  186.3300   188.28  17994726

# %%
fb_df.to_csv('facebook.csv', index=False)

# %% [markdown]
# Google

# %%
google_df = pd.read_csv('goog.csv', usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
google_df = google_df.rename(columns={
    'date': 'googledate',
    'open': 'googleopen',
    'high': 'googlehigh',
    'low': 'googlelow',
    'close': 'googleclose',
    'volume': 'googlevolume'})
google_df.head()
# Out:
#    googledate  googleopen  googlehigh  googlelow  googleclose  googlevolume
# 0  2018-01-02     1048.34     1066.94    1045.23      1065.00       1237564
# 1  2018-01-03     1064.31     1086.29    1063.21      1082.48       1430170
# 2  2018-01-04     1088.00     1093.57    1084.00      1086.40       1004605
# 3  2018-01-05     1094.00     1104.25    1092.00      1102.23       1279123
# 4  2018-01-08     1102.23     1111.27    1101.62      1106.94       1047603

# %%
google_df.to_csv('google.csv', index=False)

# %% [markdown]
# Amazon

# %%
amazon_df = pd.read_csv('amzn.csv', usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
amazon_df = amazon_df.rename(columns={
    'date': 'amazondate',
    'open': 'amazonopen',
    'high': 'amazonhigh',
    'low': 'amazonlow',
    'close': 'amazonclose',
    'volume': 'amazonvolume'})
amazon_df.head()
# Out:
#    amazondate  amazonopen  amazonhigh  amazonlow  amazonclose  amazonvolume
# 0  2018-01-02     1172.00     1190.00    1170.51      1189.01       2694494
# 1  2018-01-03     1188.30     1205.49    1188.30      1204.20       3108793
# 2  2018-01-04     1205.00     1215.87    1204.66      1209.59       3022089
# 3  2018-01-05     1217.51     1229.14    1210.00      1229.14       3544743
# 4  2018-01-08     1236.00     1253.08    1232.03      1246.87       4279475

# %%
amazon_df.to_csv('amazon.csv', index=False)

# %% [markdown]
# Apple

# %%
apple_df = pd.read_csv('aapl.csv', usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
apple_df = apple_df.rename(columns={
    'date': 'appledate',
    'open': 'appleopen',
    'high': 'applehigh',
    'low': 'applelow',
    'close': 'appleclose',
    'volume': 'applevolume'})
apple_df.head()
# Out:
#     appledate  appleopen  applehigh  applelow  appleclose  applevolume
# 0  2018-01-02   166.9271   169.0264  166.0442    168.9872     25555934
# 1  2018-01-03   169.2521   171.2337  168.6929    168.9578     29517899
# 2  2018-01-04   169.2619   170.1742  168.8106    169.7426     22434597
# 3  2018-01-05   170.1448   172.0381  169.7622    171.6751     23660018
# 4  2018-01-08   171.0375   172.2736  170.6255    171.0375     20567766

# %%
apple_df.to_csv('apple.csv', index=False)

# %% [markdown]
# Combining them together

# %%
dfs = {}
csv_files = ['google.csv', 'amazon.csv', 'apple.csv', 'facebook.csv', 'netflix.csv']
for file in csv_files:
    df_name = file.split('.')[0]
    dfs[df_name] = pd.read_csv(file)
FAANG_df = pd.concat(dfs.values(), axis=1)
FAANG_df.to_csv('FAANG.csv', index=False)

# %%
pd.read_csv('FAANG.csv')
# Out:
#      googledate  googleopen  googlehigh  googlelow  googleclose  googlevolume  \
# 0    2018-01-02     1048.34     1066.94    1045.23      1065.00       1237564
# 1    2018-01-03     1064.31     1086.29    1063.21      1082.48       1430170
# 2    2018-01-04     1088.00     1093.57    1084.00      1086.40       1004605
# 3    2018-01-05     1094.00     1104.25    1092.00      1102.23       1279123
# 4    2018-01-08     1102.23     1111.27    1101.62      1106.94       1047603
# ..          ...         ...         ...        ...          ...           ...
# 246  2018-12-24      973.90     1003.54     970.11       976.22       1590328
# 247  2018-12-26      989.01     1040.00     983.00      1039.46       2373270
# 248  2018-12-27     1017.15     1043.89     997.00      1043.88       2109777
# 249  2018-12-28     1049.62     1055.56    1033.10      1037.08       1413772
# 250  2018-12-31     1050.96     1052.70    1023.59      1035.61       1493722
#
#      amazondate  amazonopen  amazonhigh  amazonlow  ...  fbhigh     fblow  \
# 0    2018-01-02     1172.00     1190.00    1170.51  ...  181.58  177.5500
# 1    2018-01-03     1188.30     1205.49    1188.30  ...  184.78  181.3300
# 2    2018-01-04     1205.00     1215.87    1204.66  ...  186.21  184.0996
# 3    2018-01-05     1217.51     1229.14    1210.00  ...  186.90  184.9300
# 4    2018-01-08     1236.00     1253.08    1232.03  ...  188.90  186.3300
# ..          ...         ...         ...        ...  ...     ...       ...
# 246  2018-12-24     1346.00     1396.03    1307.00  ...  129.74  123.0200
# 247  2018-12-26     1368.89     1473.16    1363.01  ...  134.24  125.8900
# 248  2018-12-27     1454.20     1469.00    1390.31  ...  134.99  129.6700
# 249  2018-12-28     1473.35     1513.47    1449.00  ...  135.92  132.2000
# 250  2018-12-31     1510.80     1520.76    1487.00  ...  134.64  129.9500
#
#     fbclose  fbvolume    nflxdate  nflxopen  nflxhigh   nflxlow nflxclose  \
# 0    181.42  18151903  2018-01-02    196.10  201.6500  195.4200   201.070
# 1    184.67  16886563  2018-01-03    202.05  206.2100  201.5000   205.050
# 2    184.33  13880896  2018-01-04    206.20  207.0500  204.0006   205.630
# 3    186.85  13574535  2018-01-05    207.25  210.0200  205.5900   209.990
# 4    188.28  17994726  2018-01-08    210.02  212.5000  208.4400   212.050
# ..      ...       ...         ...       ...       ...       ...       ...
# 246  124.06  22066002  2018-12-24    242.00  250.6500  233.6800   233.880
# 247  134.18  39723370  2018-12-26    233.92  254.5000  231.2300   253.670
# 248  134.52  31202509  2018-12-27    250.11  255.5900  240.1000   255.565
# 249  133.20  22627569  2018-12-28    257.94  261.9144  249.8000   256.080
# 250  131.09  24625308  2018-12-31    260.16  270.1001  260.0000   267.660
#
#      nflxvolume
# 0      10966889
# 1       8591369
# 2       6029616
# 3       7033240
# 4       5580178
# ..          ...
# 246     9547616
# 247    14402735
# 248    12235217
# 249    10987286
# 250    13508920
#
# [251 rows x 30 columns]

# %% [markdown]
# #Files Output:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Corrected way on doing this activity

# %%
df = pd.read_csv('nflx.csv')
df['ticker'] = 'NFLX'
df.to_csv('nflx.csv', index=False)

# %%
df_fb = pd.read_csv('fb.csv')
df_fb['ticker'] = 'FB'
df_fb.to_csv('fb.csv', index=False)

# %%
df_goog = pd.read_csv('goog.csv')
df_goog['ticker'] = 'GOOG'
df_goog.to_csv('goog.csv', index=False)

# %%
df_amzn = pd.read_csv('amzn.csv')
df_amzn['ticker'] = 'AMZN'
df_amzn.to_csv('amzn.csv', index=False)

# %%
df_appl = pd.read_csv('/content/aapl.csv')
df_appl['ticker'] = 'APPL'
df_appl.to_csv('appl.csv', index=False)

# %%
dfs = {}
csv_files = ['goog.csv', 'amzn.csv', 'aapl.csv', 'fb.csv', 'nflx.csv']
for file in csv_files:
    df_name = file.split('.')[0]
    dfs[df_name] = pd.read_csv(file)
FAANG_df = pd.concat(dfs.values(), axis=1)
FAANG_df.to_csv('faang.csv', index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
FAANG_df = pd.read_csv('faang.csv')
FAANG_df.head()
# Out:
#          date     open     high      low    close   volume ticker      date.1  \
# 0  2018-01-02  1048.34  1066.94  1045.23  1065.00  1237564   GOOG  2018-01-02
# 1  2018-01-03  1064.31  1086.29  1063.21  1082.48  1430170   GOOG  2018-01-03
# 2  2018-01-04  1088.00  1093.57  1084.00  1086.40  1004605   GOOG  2018-01-04
# 3  2018-01-05  1094.00  1104.25  1092.00  1102.23  1279123   GOOG  2018-01-05
# 4  2018-01-08  1102.23  1111.27  1101.62  1106.94  1047603   GOOG  2018-01-08
#
#     open.1   high.1  ...  close.3  volume.3  ticker.2      date.4  open.4  \
# 0  1172.00  1190.00  ...   181.42  18151903        FB  2018-01-02  196.10
# 1  1188.30  1205.49  ...   184.67  16886563        FB  2018-01-03  202.05
# 2  1205.00  1215.87  ...   184.33  13880896        FB  2018-01-04  206.20
# 3  1217.51  1229.14  ...   186.85  13574535        FB  2018-01-05  207.25
# 4  1236.00  1253.08  ...   188.28  17994726        FB  2018-01-08  210.02
#
#    high.4     low.4  close.4  volume.4  ticker.3
# 0  201.65  195.4200   201.07  10966889      NFLX
# 1  206.21  201.5000   205.05   8591369      NFLX
# 2  207.05  204.0006   205.63   6029616      NFLX
# 3  210.02  205.5900   209.99   7033240      NFLX
# 4  212.50  208.4400   212.05   5580178      NFLX
#
# [5 rows x 34 columns]

# %%
df_faang = pd.read_csv('faang.csv')
df_faang['date'] = pd.to_datetime(df_faang['date'])
df_faang['volume'] = df_faang['volume'].astype(int)
df_faang_sorted = df_faang.sort_values(by=['date', 'ticker'])
df_faang_sorted.to_csv('faang_sorted.csv', index=False)

# %%
df_sorted_csv = pd.read_csv('faang_sorted.csv')
(df_sorted_csv)
# Out:
#            date     open     high      low    close   volume ticker  \
# 0    2018-01-02  1048.34  1066.94  1045.23  1065.00  1237564   GOOG
# 1    2018-01-03  1064.31  1086.29  1063.21  1082.48  1430170   GOOG
# 2    2018-01-04  1088.00  1093.57  1084.00  1086.40  1004605   GOOG
# 3    2018-01-05  1094.00  1104.25  1092.00  1102.23  1279123   GOOG
# 4    2018-01-08  1102.23  1111.27  1101.62  1106.94  1047603   GOOG
# ..          ...      ...      ...      ...      ...      ...    ...
# 246  2018-12-24   973.90  1003.54   970.11   976.22  1590328   GOOG
# 247  2018-12-26   989.01  1040.00   983.00  1039.46  2373270   GOOG
# 248  2018-12-27  1017.15  1043.89   997.00  1043.88  2109777   GOOG
# 249  2018-12-28  1049.62  1055.56  1033.10  1037.08  1413772   GOOG
# 250  2018-12-31  1050.96  1052.70  1023.59  1035.61  1493722   GOOG
#
#          date.1   open.1   high.1  ...  close.3  volume.3  ticker.2  \
# 0    2018-01-02  1172.00  1190.00  ...   181.42  18151903        FB
# 1    2018-01-03  1188.30  1205.49  ...   184.67  16886563        FB
# 2    2018-01-04  1205.00  1215.87  ...   184.33  13880896        FB
# 3    2018-01-05  1217.51  1229.14  ...   186.85  13574535        FB
# 4    2018-01-08  1236.00  1253.08  ...   188.28  17994726        FB
# ..          ...      ...      ...  ...      ...       ...       ...
# 246  2018-12-24  1346.00  1396.03  ...   124.06  22066002        FB
# 247  2018-12-26  1368.89  1473.16  ...   134.18  39723370        FB
# 248  2018-12-27  1454.20  1469.00  ...   134.52  31202509        FB
# 249  2018-12-28  1473.35  1513.47  ...   133.20  22627569        FB
# 250  2018-12-31  1510.80  1520.76  ...   131.09  24625308        FB
#
#          date.4  open.4    high.4     low.4  close.4  volume.4  ticker.3
# 0    2018-01-02  196.10  201.6500  195.4200  201.070  10966889      NFLX
# 1    2018-01-03  202.05  206.2100  201.5000  205.050   8591369      NFLX
# 2    2018-01-04  206.20  207.0500  204.0006  205.630   6029616      NFLX
# 3    2018-01-05  207.25  210.0200  205.5900  209.990   7033240      NFLX
# 4    2018-01-08  210.02  212.5000  208.4400  212.050   5580178      NFLX
# ..          ...     ...       ...       ...      ...       ...       ...
# 246  2018-12-24  242.00  250.6500  233.6800  233.880   9547616      NFLX
# 247  2018-12-26  233.92  254.5000  231.2300  253.670  14402735      NFLX
# 248  2018-12-27  250.11  255.5900  240.1000  255.565  12235217      NFLX
# 249  2018-12-28  257.94  261.9144  249.8000  256.080  10987286      NFLX
# 250  2018-12-31  260.16  270.1001  260.0000  267.660  13508920      NFLX
#
# [251 rows x 34 columns]

# %% [markdown]
# 7 rows with highes values

# %%
df_faang = pd.read_csv('faang.csv')
top_volume = df_faang.nlargest(7, 'volume')
(top_volume)
# Out:
#            date     open     high      low    close   volume ticker  \
# 22   2018-02-02  1122.00  1123.07  1107.28  1111.90  4857943   GOOG
# 77   2018-04-24  1052.00  1057.00  1010.59  1019.98  4760260   GOOG
# 245  2018-12-21  1015.30  1024.02   973.69   979.54  4595891   GOOG
# 182  2018-09-21  1192.00  1192.21  1166.04  1166.09  4405584   GOOG
# 207  2018-10-26  1037.03  1106.53  1034.09  1071.47  4187586   GOOG
# 208  2018-10-29  1082.47  1097.04   995.83  1020.08  3880723   GOOG
# 23   2018-02-05  1090.60  1110.00  1052.03  1055.80  3798301   GOOG
#
#          date.1   open.1   high.1  ...  close.3  volume.3  ticker.2  \
# 22   2018-02-02  1477.39  1498.00  ...   190.28  26677484        FB
# 77   2018-04-24  1535.80  1539.50  ...   159.69  35079926        FB
# 245  2018-12-21  1464.99  1480.00  ...   124.95  56901491        FB
# 182  2018-09-21  1954.22  1957.31  ...   162.93  45994800        FB
# 207  2018-10-26  1649.59  1698.46  ...   145.37  31303341        FB
# 208  2018-10-29  1660.00  1665.74  ...   142.09  31336784        FB
# 23   2018-02-05  1402.62  1458.98  ...   181.26  33128206        FB
#
#          date.4    open.4   high.4   low.4  close.4  volume.4  ticker.3
# 22   2018-02-02  263.0000  270.620  262.71   267.43   9123610      NFLX
# 77   2018-04-24  319.2168  320.249  302.31   307.02  13893217      NFLX
# 245  2018-12-21  263.8300  264.500  241.29   246.39  21397595      NFLX
# 182  2018-09-21  366.5900  372.220  360.74   361.19  11930568      NFLX
# 207  2018-10-26  300.5100  313.990  292.30   299.83  19616041      NFLX
# 208  2018-10-29  305.2600  307.890  275.40   284.84  21698841      NFLX
# 23   2018-02-05  262.0000  267.899  250.03   254.26  11896053      NFLX
#
# [7 rows x 34 columns]

# %% [markdown]
# Using melt()

# %%
df_faang = pd.read_csv('faang.csv')
df_long_format = pd.melt(df_faang, id_vars=['date', 'ticker'], value_vars=['open', 'high', 'low', 'close', 'volume'], var_name='variable', value_name='value')
(df_long_format)
# Out:
#             date ticker variable       value
# 0     2018-01-02   GOOG     open     1048.34
# 1     2018-01-03   GOOG     open     1064.31
# 2     2018-01-04   GOOG     open     1088.00
# 3     2018-01-05   GOOG     open     1094.00
# 4     2018-01-08   GOOG     open     1102.23
# ...          ...    ...      ...         ...
# 1250  2018-12-24   GOOG   volume  1590328.00
# 1251  2018-12-26   GOOG   volume  2373270.00
# 1252  2018-12-27   GOOG   volume  2109777.00
# 1253  2018-12-28   GOOG   volume  1413772.00
# 1254  2018-12-31   GOOG   volume  1493722.00
#
# [1255 rows x 4 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import requests, csv
from bs4 import BeautifulSoup
url = "https://nhfr.doh.gov.ph/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    hospitals = soup.find_all('div', class_='hospital')
    hospital_data = []
    for hospital in hospitals:
        name = hospital.find('h2').text.strip()
        address = hospital.find('p', class_='address').text.strip()
        contact = hospital.find('p', class_='contact').text.strip()
        hospital_data.append({'Name': name, 'Address': address, 'Contact': contact})
    with open('hospital.csv', 'w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=['Name', 'Address', 'Contact'])
        writer.writeheader()
        writer.writerows(hospital_data)

# %%
pd.read_csv('hospital.csv')
# Out:
#       index  Provider ID                       Hospital Name  \
# 0         0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1         1        10032                    WEDOWEE HOSPITAL
# 2         2        10131            CRESTWOOD MEDICAL CENTER
# 3         3        20001    PROVIDENCE ALASKA MEDICAL CENTER
# 4         4        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# ...     ...          ...                                 ...
# 4813   4813       501333  KITTITAS VALLEY COMMUNITY HOSPITAL
# 4814   4814       450827         KELL WEST REGIONAL HOSPITAL
# 4815   4815       501310          NEWPORT COMMUNITY HOSPITAL
# 4816   4816       670107     BAYLOR EMERGENCY MEDICAL CENTER
# 4817   4817       450213            UNIVERSITY HEALTH SYSTEM
#
#                             Address           City State  ZIP Code  \
# 0        2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 1             209 NORTH MAIN STREET        WEDOWEE    AL     36278
# 2                ONE HOSPITAL DR SE     HUNTSVILLE    AL     35801
# 3                        BOX 196604      ANCHORAGE    AK     99508
# 4                        PO BOX 287         BETHEL    AK     99559
# ...                             ...            ...   ...       ...
# 4813             603 SOUTH CHESTNUT     ELLENSBURG    WA     98926
# 4814       5402 KELL WEST BOULEVARD  WICHITA FALLS    TX     76310
# 4815           714 WEST PINE STREET        NEWPORT    WA     99156
# 4816  12500 SOUTH FREEWAY SUITE 100       BURLESON    TX     76028
# 4817                4502 MEDICAL DR    SAN ANTONIO    TX     78229
#
#        County Name  Phone Number              Hospital Type  ...  \
# 0         MARSHALL    2565938310       Acute Care Hospitals  ...
# 1         RANDOLPH    2563572111       Acute Care Hospitals  ...
# 2          MADISON    2568823100       Acute Care Hospitals  ...
# 3        ANCHORAGE    9072123675       Acute Care Hospitals  ...
# 4           BETHEL    9075436300       Acute Care Hospitals  ...
# ...            ...           ...                        ...  ...
# 4813      KITTITAS    5099629841  Critical Access Hospitals  ...
# 4814       WICHITA    9406925888       Acute Care Hospitals  ...
# 4815  PEND OREILLE    5094472441  Critical Access Hospitals  ...
# 4816       JOHNSON    2142946250       Acute Care Hospitals  ...
# 4817         BEXAR    2103584000       Acute Care Hospitals  ...
#
#                Readmission national comparison footnote  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4813                                                NaN
# 4814                                                NaN
# 4815                                                NaN
# 4816  Results are not available for this reporting p...
# 4817                                                NaN
#
#       Patient experience national comparison  \
# 0               Same as the National average
# 1                              Not Available
# 2               Same as the National average
# 3                 Below the National average
# 4                 Below the National average
# ...                                      ...
# 4813              Above the National average
# 4814              Above the National average
# 4815                           Not Available
# 4816                           Not Available
# 4817            Same as the National average
#
#         Patient experience national comparison footnote  \
# 0                                                   NaN
# 1     Results are not available for this reporting p...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4813                                                NaN
# 4814                                                NaN
# 4815  Results are not available for this reporting p...
# 4816  Results are not available for this reporting p...
# 4817                                                NaN
#
#       Effectiveness of care national comparison  \
# 0                  Same as the National average
# 1                  Same as the National average
# 2                  Same as the National average
# 3                    Below the National average
# 4                    Below the National average
# ...                                         ...
# 4813               Same as the National average
# 4814               Same as the National average
# 4815                              Not Available
# 4816                              Not Available
# 4817               Same as the National average
#
#      Effectiveness of care national comparison footnote  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4813                                                NaN
# 4814                                                NaN
# 4815  Results are not available for this reporting p...
# 4816  Results are not available for this reporting p...
# 4817                                                NaN
#
#      Timeliness of care national comparison  \
# 0                Above the National average
# 1              Same as the National average
# 2              Same as the National average
# 3                Below the National average
# 4                             Not Available
# ...                                     ...
# 4813           Same as the National average
# 4814           Same as the National average
# 4815                          Not Available
# 4816           Same as the National average
# 4817             Below the National average
#
#         Timeliness of care national comparison footnote  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Results are not available for this reporting p...
# ...                                                 ...
# 4813                                                NaN
# 4814                                                NaN
# 4815  Results are not available for this reporting p...
# 4816                                                NaN
# 4817                                                NaN
#
#      Efficient use of medical imaging national comparison  \
# 0                            Below the National average
# 1                                         Not Available
# 2                          Same as the National average
# 3                          Same as the National average
# 4                                         Not Available
# ...                                                 ...
# 4813                       Same as the National average
# 4814                       Same as the National average
# 4815                                      Not Available
# 4816                                      Not Available
# 4817                         Below the National average
#
#      Efficient use of medical imaging national comparison footnote  \
# 0                                                   NaN
# 1     Results are not available for this reporting p...
# 2                                                   NaN
# 3                                                   NaN
# 4     Results are not available for this reporting p...
# ...                                                 ...
# 4813                                                NaN
# 4814                                                NaN
# 4815  Results are not available for this reporting p...
# 4816  Results are not available for this reporting p...
# 4817                                                NaN
#
#                                                Location
# 0          2505 U S HIGHWAY 431 NORTH\nBOAZ, AL 35957\n
# 1            209 NORTH MAIN STREET\nWEDOWEE, AL 36278\n
# 2            ONE HOSPITAL DR SE\nHUNTSVILLE, AL 35801\n
# 3                     BOX 196604\nANCHORAGE, AK 99508\n
# 4                        PO BOX 287\nBETHEL, AK 99559\n
# ...                                                 ...
# 4813  603 SOUTH CHESTNUT\nELLENSBURG, WA 98926\n(46....
# 4814  5402 KELL WEST BOULEVARD\nWICHITA FALLS, TX 76...
# 4815  714 WEST PINE STREET\nNEWPORT, WA 99156\n(48.1...
# 4816  12500 SOUTH FREEWAY SUITE 100\nBURLESON, TX 76...
# 4817  4502 MEDICAL DR\nSAN ANTONIO, TX 78229\n(29.50...
#
# [4818 rows x 30 columns]

# %%
hospital_df = pd.read_csv('hospital.csv')
hospital_df['date'] = pd.to_datetime(df_faang['date'])
hospital_df_sorted = hospital_df.sort_values(by=['date'])
hospital_df_sorted.to_csv('hospital.csv', index=False)

# %% [markdown]
# #Conclusion

# %% [markdown]
# Even though I had to check the libraries and get references online it was such a great experience to do this since I was able to get data through functions and know I see the sorting of our simple file managers in a new light still kinda confusing though

# %%
,,,,,
